# %%
#Wordcloud is a separate library used to handle the plotting of text into an image
# !pip install wordcloud

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

#Reading the data
phone_df = pd.read_csv("IPhoneReview.csv",encoding='latin') 
phone_df
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\shiva kumar\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\shiva kumar\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\shiva kumar\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shiva kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\shiva kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shiva kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shiva kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\shiva kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\shiva kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shiva kumar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\shiva kumar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    -- ------------------------------------ 20.5/300.2 kB 131.3 kB/s eta 0:00:03
#    --------- ----------------------------- 71.7/300.2 kB 435.7 kB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
#       Unnamed: 0         Date  \
# 0              0  16 Jan 2018
# 1              1  16 Jan 2018
# 2              2  16 Jan 2018
# 3              3  16 Jan 2018
# 4              4  16 Jan 2018
# ...          ...          ...
# 1995        1995  12 Sep 2017
# 1996        1996  12 Sep 2017
# 1997        1997  12 Sep 2017
# 1998        1998  12 Sep 2017
# 1999        1999  12 Sep 2017
#
#                                                  Review   UserName
# 0     mir, 16 Jan 2018My Huawei Mate 10 Pro is alrea...      Mr No
# 1     This month it fell from 1149Â? to 999Â? in Ger...  Anonymous
# 2     chopp, 16 Jan 2018hey guys iam confused betwee...  Anonymous
# 3     chopp, 16 Jan 2018hey guys iam confused betwee...       Tony
# 4     hey guys iam confused between buying iphone x ...  Anonymous
# ...                                                 ...        ...
# 1995  Funny how Android guys react to this phone and...  Anonymous
# 1996  This is the most ugly phone i have ever seen. ...  Daniel M.
# 1997  No Headphone jack. PPI < 500. For a flagship W...  Anonymous
# 1998                          no fingerprint sensor :))       alex
# 1999  Will Samsung be making that screen? :)\r\n \r\...    Michael
#
# [2000 rows x 4 columns]

# %%
#The following part of code helps to concatenate the text of the relevant column into a single string
word_string = ''
stopwords = set(STOPWORDS)
for comments in phone_df.Review.values:
    word_string = word_string + comments
wordcloud = WordCloud(background_color='black',stopwords=stopwords).generate(word_string)

# %%
#Creating the canvas
fig = plt.figure()
fig.set_figwidth(14)
fig.set_figheight(18)
#Plotting the Wordcloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#To add more words to the list of stopwords.
stopwords.add('phone')
stopwords.add('iPhone')

# %%
#Alternatively generating the wordcloud first 
wordcloud.generate(word_string)
#Now displaying the cloud
fig = plt.figure()
fig.set_figwidth(14) 
fig.set_figheight(18) 
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')#Since we do not need labels on axes for a Wordcloud
plt.show()

# %%
#importing necessary libraries
from skimage.io import imread
from skimage import data_dir
#reading an image to set the custom outline of Wordcloud
cloud = imread('cloud.png')
plt.imshow(cloud)

# %%
#plotting the custom Wordcloud
wc1 = WordCloud(stopwords=stopwords,max_words=50,background_color='white',mask = cloud)
wc1.generate(word_string)
fig = plt.figure()
fig.set_figwidth(10) 
fig.set_figheight(16) 
plt.imshow(wc1, interpolation='bilinear')
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
